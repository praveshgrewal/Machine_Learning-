# %% [markdown]
# in python modules and packages help organize and reuse code. here a comprehensive guide on how to import them

# %%
#import module
import math

math.sqrt(16)
# Out:
# 4.0

# %%
#import function from module
from math import sqrt,pi

print(sqrt(16))
print(pi)
# Out:
# 4.0
# 3.141592653589793

# %%
# !pip install numpy
# Out:
# ...
#      ---------------------------------------- 0.0/60.9 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/60.9 kB ? eta -:--:--
#      ------------------------- ------------ 41.0/60.9 kB 393.8 kB/s eta 0:00:01
#      -------------------------------------- 60.9/60.9 kB 544.7 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/16.2 MB ? eta -:--:--
#    ---------------------------------------- 0.1/16.2 MB 3.2 MB/s eta 0:00:06
#    ---------------------------------------- 0.2/16.2 MB 2.9 MB/s eta 0:00:06
#     --------------------------------------- 0.3/16.2 MB 2.9 MB/s eta 0:00:06
#    - -------------------------------------- 0.5/16.2 MB 3.1 MB/s eta 0:00:06
#    - -------------------------------------- 0.6/16.2 MB 2.9 MB/s eta 0:00:06
#    - -------------------------------------- 0.8/16.2 MB 3.0 MB/s eta 0:00:06
#    -- ------------------------------------- 0.9/16.2 MB 3.0 MB/s eta 0:00:06
# ...

# %%
import numpy as np

# %%
from math import *

sqrt(16)
# Out:
# 4.0

# %%
from package.math import addition
addition(2,8)
# Out:
# 10

# %%
from package import math
math.addition(2,8)
# Out:
# 10

# %%
from package.math import *
addition(2,8)
# Out:
# 10

# %%
#from subpackage import multiple
from package.subpackages.multi import multiple
multiple(2,8)
# Out:
# 16
